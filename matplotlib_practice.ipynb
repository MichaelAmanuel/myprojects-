# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0, 5, 11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x, y)

# %%
plt.plot(x, y)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
plt.subplot(1, 2, 1)
plt.plot(x, y, 'r')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Title')

plt.subplot(1, 2, 2)
plt.plot(y, x, 'b')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig = plt.figure()

axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])

axes.plot(x, y)
axes.set_xlabel('X-Label')
axes.set_ylabel('Y-Label')
# Out:
# Text(0, 0.5, 'Y-Label')

# %%
fig = plt.figure()
axes_2 = fig.add_axes([0.4, 0.4, 0.5, 0.5])

axes_2.plot(y, x)

# %%
fig  = plt.figure()

axes_1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes_2 = fig.add_axes([0.2, 0.5, 0.4, 0.3])

# %%
fig  = plt.figure()

axes_1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes_2 = fig.add_axes([0.2, 0.5, 0.4, 0.3])

axes_1.plot(x, y)
axes_2.plot(y, x)

# %%
fig  = plt.figure()

axes_1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes_2 = fig.add_axes([0.2, 0.5, 0.4, 0.3])

axes_1.plot(x, y)
axes_1.set_title('Large-Plot')

axes_2.plot(y, x)
axes_2.set_title('Small-Plot')
# Out:
# Text(0.5, 1.0, 'Small-Plot')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

axes[0].plot(x, y)
axes[0].set_xlabel('X-Label')
axes[0].set_ylabel('Y-Label')

axes[1].plot(y, x)
axes[1].set_xlabel('X-Label')
axes[1].set_ylabel('Y-Label')
# Out:
# Text(0, 0.5, 'Y-Label')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

axes[0].plot(x, y)
axes[0].set_xlabel('X-Label')
axes[0].set_ylabel('Y-Label')

axes[1].plot(y, x)
axes[1].set_xlabel('X-Label')
axes[1].set_ylabel('Y-Label')

plt.tight_layout()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

for current_ax in axes:
  current_ax.plot(x, y)

# %%
fig = plt.figure(figsize=(3,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(x, y)

# %%
fig, axes = plt.subplots(nrows=2, ncols= 1, figsize=(8,2))


axes[0].plot(x, y)
axes[1].plot(y, x)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x, y)
ax.plot(y, x)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x, x**2)
ax.plot(x, x**3)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x, x**2, label= 'X Squared')
ax.plot(x, x**3, label = 'X Cubed')

ax.legend()

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x, x**2, label= 'X Squared')
ax.plot(x, x**3, label = 'X Cubed')

ax.legend(loc=5)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, y, color= 'orange')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, y, color= 'orange', lw= 3, alpha=0.6)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, y, color= 'orange', lw= 3, alpha=0.6, linestyle='--')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, y, color= 'orange', lw= 3, alpha=0.6, ls='dotted')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, y, color= 'orange', lw= 3, alpha=0.6, ls='dotted', marker='1',markersize=20 )

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, y, color= 'orange', lw= 3, alpha=0.6, ls='dotted', marker='o',
        markersize=10, markerfacecolor='red')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, y, color= 'purple', lw= 3,ls='--')

ax.set_xlim([0,1])
ax.set_ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
fig.savefig('my_picture.png', dpi=200)

# %%
x = np.arange(0, 100)
y = x * 2
z = x ** 2
